# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import urllib.request
import os

# %%
path = "/content/drive/My Drive"
os.chdir(path)
os.listdir(path)
# Out:
# ['Colab Notebooks', 'CNN.png', 'MLP.weights.best.hdf5']

# %%
url="http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic3.xls"
filepath="/content/drive/My Drive/titanic3.xls"
if not os.path.isfile(filepath):
  result=urllib.request.urlretrieve(url,filepath)
  print('downloaded:',result)
# Out:
# downloaded: ('/content/drive/My Drive/titanic3.xls', <http.client.HTTPMessage object at 0x7fcdcf381278>)

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing

# %%
all_df = pd.read_excel(filepath)

# %%
def PreprocessData(raw_df):
  df = raw_df.drop(['name'],axis=1)
  age_mean = df['age'].mean()
  df['age'] = df['age'].fillna[age_mean]
  fare_mean = df['fare'].mean()
  df['fare'] = df['fare'].fillna[fare_mean]
  df['sex'] = df['sex'].map({'female':0, 'male':1}).astype(int)
  x_OneHot_df = pd.get_dummies(data=df,colums=["embraked"])

  ndarray  = x_OneHot_df.values
  Features = ndarray[:, 1:]
  Label = ndarray[:, 0]

  minmax_scale = preprocessing.MinMaxScaler(feature_range=(0,1))
  scaledFeatures = minmax_scale.fit_transform(Features)

  return scaledFeatures, Label
